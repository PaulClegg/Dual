# %%
import pytest
import sys
import os
import numpy as np

HOME="/home/jovyan/work"

sys.path.insert(0, HOME + '/Dual/src')
import activities as tpA
import simulation as tpS
sys.path.insert(0, HOME + '/IDIF/src')
import PET_tools as tpT

import sirf.STIR as tpPET

# %%
    data_stem = HOME + "/Dual/data"
    filename = "atten_table.dat"
    path = os.path.join(data_stem, filename)

    atten_dict = tpA.readAttenuation(path)
    for key, value in atten_dict.items():
        print(f"atten_dict[{key}] = {value}")
# Out:
# /home/jovyan/work/Dual/data/atten_table.dat
# atten_dict[E] = 511.0
# atten_dict[water] = 0.095996585
# atten_dict[muscle] = 0.09986592
# atten_dict[lung] = 0.024750552
# atten_dict[dry_spine] = 0.13037411
# atten_dict[dry_rib] = 0.17161947
# atten_dict[adipose] = 0.088862527
# atten_dict[blood] = 0.10081735
# atten_dict[heart] = 0.10004309
# atten_dict[kidney] = 0.099953854
# atten_dict[liver] = 0.10081045
# atten_dict[lymph] = 0.098498107
# atten_dict[pancreas] = 0.099260214
# atten_dict[intestine] = 0.098320903
# atten_dict[skull] = 0.1460689
# atten_dict[cartilage] = 0.10400932
# atten_dict[brain] = 0.099343632
# atten_dict[spleen] = 0.10090723
# atten_dict[iodine_blood] = 0.10376212
# atten_dict[iron] = 0.6544427
# atten_dict[pmma] = 0.11090614
# atten_dict[aluminum] = 0.22541228
# atten_dict[titanium] = 0.3673705
# atten_dict[air] = 0.00010409389
# atten_dict[graphite] = 0.15717162
# atten_dict[lead] = 1.7711832
# atten_dict[breast_mammary] = 0.097339
# atten_dict[skin] = 0.10347148
# atten_dict[iodine] = 0.46925474
# atten_dict[eye_lens] = 0.10122136
# atten_dict[ovary] = 0.10013715
# atten_dict[red_marrow] = 0.098188353
# atten_dict[yellow_marrow] = 0.094230634
# atten_dict[testis] = 0.099273487
# atten_dict[thyroid] = 0.10005649
# atten_dict[bladder] = 0.099178544
