# %%
import pytest
import sys
import os
import numpy as np

HOME="/home/jovyan/work"

sys.path.insert(0, HOME + '/Dual/src')
import activities as tpA
import simulation as tpS
sys.path.insert(0, HOME + '/IDIF/src')
import PET_tools as tpT

import sirf.STIR as tpPET

# %%
    data_stem = HOME + "/Dual/data"
    filename = "atten_table.dat"
    path = os.path.join(data_stem, filename)

    organ_names, attenuations = tpA.readAttenuation(path)
    for pair in zip(organ_names, attenuations):
        print(pair)
# Out:
# /home/jovyan/work/Dual/data/atten_table.dat
# ['E', 'water', 'muscle', 'lung', 'dry_spine', 'dry_rib', 'adipose', 'blood', 'heart', 'kidney', 'liver', 'lymph', 'pancreas', 'intestine', 'skull', 'cartilage', 'brain', 'spleen', 'iodine_blood', 'iron', 'pmma', 'aluminum', 'titanium', 'air', 'graphite', 'lead', 'breast_mammary', 'skin', 'iodine', 'eye_lens', 'ovary', 'red_marrow', 'yellow_marrow', 'testis', 'thyroid', 'bladder']
# ['511.0', '0.095996585', '0.09986592', '0.024750552', '0.13037411', '0.17161947', '0.088862527', '0.10081735', '0.10004309', '0.099953854', '0.10081045', '0.098498107', '0.099260214', '0.098320903', '0.1460689', '0.10400932', '0.099343632', '0.10090723', '0.10376212', '0.6544427', '0.11090614', '0.22541228', '0.3673705', '0.00010409389', '0.15717162', '1.7711832', '0.097339', '0.10347148', '0.46925474', '0.10122136', '0.10013715', '0.098188353', '0.094230634', '0.099273487', '0.10005649', '0.099178544']
